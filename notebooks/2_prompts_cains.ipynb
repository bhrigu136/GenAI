# %%
# from langchain_openai import ChatOpenAI
# llm = ChatOpenAI(model="gpt-3.5-turbo")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model ="gemini-2.5-flash-lite")

# %%
prompts = [
    {"role":"system", "content": "You are a python developer."},
    {"role":"user", "content": "Difference between list and tuple in python ?"},
]
res = llm.invoke(prompts)
print(res.content)
# Out:
# In Python, both lists and tuples are used to store collections of items. However, they have a fundamental difference: **mutability**.
#
# Here's a breakdown of their differences:
#
# | Feature        | List                                 | Tuple                                |
# |----------------|--------------------------------------|--------------------------------------|
# | **Mutability** | **Mutable** (can be changed after creation) | **Immutable** (cannot be changed after creation) |
# | **Syntax**     | Defined using square brackets `[]`   | Defined using parentheses `()`       |
# | **Performance**| Generally slower due to overhead of mutability | Generally faster due to immutability |
# | **Use Cases**  | Storing collections that need to be modified, like user inputs, dynamic data. | Storing fixed collections, like coordinates, database records, function return values. |
# ...

# %%
prompts = [
    {"role":"system", "content": "You are a JavaScript developer."},
    {"role":"user", "content": "Difference between map and filter ?"},
]
res = llm.invoke(prompts)
print(res.content)
# Out:
# In JavaScript, both `map()` and `filter()` are powerful array methods that allow you to transform and manipulate arrays. However, they serve distinct purposes:
#
# Here's a breakdown of their differences:
#
# **`map()`**
#
# *   **Purpose:** To **transform** each element in an array into a new element, creating a **new array of the same length** as the original.
# *   **How it works:** It iterates over each element of an array, applies a provided callback function to that element, and then collects the return values of the callback function into a new array.
# *   **Return Value:** Always returns a **new array** with the same number of elements as the original array.
# *   **Callback Function:** The callback function for `map()` is expected to **return a value**. This returned value will be the corresponding element in the new array.
# *   **Use Cases:**
#     *   Doubling all numbers in an array.
#     *   Converting an array of strings to their uppercase versions.
# ...

# %%
prompts = [
    {"role":"system", "content": "You are a translator and translate input in hindi ?"},
    {"role":"user", "content": "I love to play cricket ?"},
]
res = llm.invoke(prompts)
print(res.content)
# Out:
# मुझे क्रिकेट खेलना बहुत पसंद है।

# %% [markdown]
# #### Prompt Templates- Dynamic Prompts

# %%
# from langchain_openai import ChatOpenAI
# from langchain_core.prompts import ChatPromptTemplate

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash-lite")
out = StrOutputParser()

# %%
#### My self Chain Node

def transform_case(result: str):
    return result.upper()

# %%
prompts = ChatPromptTemplate.from_messages([
    {"role":"system", "content": "You are a translator and translate input in {language} ?"},
    {"role":"user", "content": "{query}"},
])

# %%
final_prompts = prompts.format_messages(language="hindi", query="I love to play football.")
# final_prompts
res = llm.invoke(final_prompts)
print(res.content)
# Out:
# मुझे फुटबॉल खेलना बहुत पसंद है।

# %%
res = llm.invoke(prompts.invoke({"language":"hindi", "query":"I love to play football."}))
res.content
# Out:
# 'मुझे फुटबॉल खेलना बहुत पसंद है।'

# %% [markdown]
# #### Chains - Runnable

# %%
chains = prompts | llm | out | transform_case

# %%
chains
# Out:
# ChatPromptTemplate(input_variables=['language', 'query'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['language'], input_types={}, partial_variables={}, template='You are a translator and translate input in {language} ?'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['query'], input_types={}, partial_variables={}, template='{query}'), additional_kwargs={})])
# ...

# %%
res = chains.invoke({"language":"Hinglish", "query":"I love to play football."})
print(res)
# Out:
# MAIN FOOTBALL KHELNA PASAND KARTA HOON.
