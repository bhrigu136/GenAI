# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langgraph.checkpoint.memory import MemorySaver

# %%
model = ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
agent = create_agent(
    model=model,
    tools=[search.run],
    system_prompt="You are a agent and can search for any question on google.",
    checkpointer=MemorySaver()
)

# %%
# question = "Who won the Woman's World Cup 2025?"

question = "what is the total score?"

# %%
response = agent.invoke(
        {"messages":[{"role":"user", "content":question}]},
        {"configurable": {"thread_id": "1"}},
    )

# %%
print(response["messages"][-1].content)
# Out:
# In the 2025 ICC Women’s Cricket World Cup final at DY Patil Stadium, the scorecards were:
#
# | Team | Innings | Runs / Wickets |
# |------|---------|----------------|
# | **India (Women)** | 1st | **298 / 7** (50 overs) |
# | **South Africa (Women)** | 2nd | **246 / 10** (50 overs) |
#
# India chased the target comfortably, winning by 52 runs to claim their maiden Women’s World Cup title.

# %%
# question = "what is the total score?"
