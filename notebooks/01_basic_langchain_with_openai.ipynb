# %% [markdown]
# ##### Load Env Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-5-nano-2025-08-07")
# Out:
# c:\Users\taman\Desktop\Pythonds\GENAI\env\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
res = llm.invoke("who is pm of india?")
print(res.content)
# Out:
# Narendra Modi. He has been Prime Minister of India since May 2014 and was re-elected in 2019. If you want the exact current status today, I can check the latest sources for you.
