# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash")

# %% [markdown]
# #### Discuss the problem first.

# %%
text = "Hello, My name is Tamanna," \
     "Email is tamannabhrigunath@gmail.com and my age is 21"

# %%
res = llm.invoke(f"Please give me only name, email and age from this text: {text}")

# %%
print(res.content)
# Out:
# Name: Tamanna
# Email: tamannabhrigunath@gmail.com
# Age: 21

# %%
print(type(res.content))
# Out:
# <class 'str'>

# %% [markdown]
# #### Solution is: Structured Output.

# %%
from pydantic import BaseModel, Field
from typing import List

class ResponseStructure(BaseModel):
    name:str = Field(description="Complete Name")
    email:str = Field(description="Email Address")
    age:int = Field(description="Age")

structured_llm = llm.with_structured_output(ResponseStructure)

# %%
structured_llm.invoke(f"Please give me only name, email and age from text")
# Out:
# ResponseStructure(name='', email='', age=0)

# %%
res.model_dump()
# Out:
# {'content': 'Name: Tamanna\nEmail: tamannabhrigunath@gmail.com\nAge: 21',
#  'additional_kwargs': {},
#  'response_metadata': {'finish_reason': 'STOP',
#   'model_name': 'gemini-2.5-flash',
#   'safety_ratings': [],
#   'model_provider': 'google_genai'},
#  'type': 'ai',
#  'name': None,
#  'id': 'lc_run--019bf4bb-a8c1-7bb1-b101-305c3aa08359-0',
#  'tool_calls': [],
#  'invalid_tool_calls': [],
#  'usage_metadata': {'input_tokens': 42,
#   'output_tokens': 90,
#   'total_tokens': 132,
#   'input_token_details': {'cache_read': 0},
#   'output_token_details': {'reasoning': 66}}}

# %%
class Movies(BaseModel):
    title:str = Field(description="Movie Title")
    year:int = Field(description="Movie Released Year.")

class AllMoviews(BaseModel):
    movies:List[Movies]

movie_llm = llm.with_structured_output(AllMoviews)

# %%
res = movie_llm.invoke("Give me three Sci-fi movie")

# %%
res
# Out:
# AllMoviews(movies=[Movies(title='Inception', year=2010), Movies(title='Blade Runner 2049', year=2017), Movies(title='Dune', year=2021)])
