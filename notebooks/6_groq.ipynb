# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI
# Out:
# c:\Users\taman\Desktop\Pythonds\GENAI\env\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
# openaiLLm = ChatOpenAI(model="gpt-5")

# %%
res = llm.invoke("Who is PM of India ?")
print(res.content)
# Out:
# The current Prime Minister of India is **Narendra Modi**. He has been in office since May 26, 2014, following his party (the Bharatiya Janata Party) winning a decisive majority in the general elections. Modi was re‑elected in 2019 and continues to serve as PM as of 2026.

# %%
res = llm.invoke("Can you explain me GEN-AI ?")

# %%
print(res.content)
# Out:
# ### What is Generative AI (Gen‑AI)?
#
# **Generative AI** refers to a class of artificial‑intelligence models that can **create new content**—text, images, audio, video, code, or even 3D models—by learning patterns from large amounts of existing data. Unlike classic AI that only classifies or predicts, generative models **“generate”** something that didn’t exist before.
#
# ---
#
# ## Core Ideas Behind Generative AI
#
# | Concept | What It Means | How It Works (in a nutshell) |
# |---------|---------------|------------------------------|
# | **Training Data** | Huge datasets (books, websites, photos, music, etc.) | The model sees billions of examples and learns statistical regularities. |
# | **Latent Space** | A compressed representation of data | The model learns a low‑dimensional space where similar items are close together. |
# | **Probabilistic Modeling** | Predicts the next element (word, pixel, note) | Uses probability distributions to decide what to output next. |
# | **Neural Architecture** | Transformers, Diffusion, GANs, etc. | Different architectures are suited for different modalities. |
# | **Fine‑Tuning & Prompting** | Adapting a base model to a specific task | You can steer the model with prompts or additional training data. |
#
# ---
#
# ## Popular Generative Models
#
# | Modality | Model | How It Generates |
# |----------|-------|------------------|
# | **Text** | GPT‑4, Claude, LLaMA | Uses a transformer to predict the next token; iteratively samples tokens to form sentences. |
# | **Images** | DALL·E 3, Stable Diffusion, Midjourney | Diffusion models start from noise and iteratively refine it into an image guided by a text prompt. |
# | **Audio** | Jukebox, AudioLM | Generates waveforms or spectrograms conditioned on text or prior audio. |
# | **Video** | VideoGPT, Phenaki | Extends image diffusion over time; predicts frames conditioned on earlier frames and prompts. |
# | **Code** | GitHub Copilot, CodeGen | Trained on public code repositories; predicts next token in code. |
#
# ---
#
# ## How the Technology Works (High‑Level Flow)
#
# 1. **Data Collection**
#    Gather millions of examples (text, images, etc.).
#
# 2. **Pre‑Training**
#    Train a large neural network to predict missing parts of the data (next word, next pixel, etc.).
#    - *Transformer* models use self‑attention to capture long‑range dependencies.
#    - *Diffusion* models learn to reverse a noise‑addition process.
#
# 3. **Fine‑Tuning / Prompt Engineering**
#    Adapt the base model to a specific task or domain.
#    - Example: Fine‑tune GPT‑4 on medical literature to produce better medical QA.
#
# 4. **Inference / Generation**
#    Provide a prompt or seed; the model samples from its learned distribution to produce new content.
#
# 5. **Post‑Processing (optional)**
#    Clean up artifacts, enforce constraints, or combine multiple modalities.
#
# ---
#
# ## Why It Matters
#
# | Benefit | Explanation |
# |---------|-------------|
# | **Productivity** | Automates drafting emails, coding, design mock‑ups. |
# | **Creativity** | Helps artists, writers, musicians brainstorm and prototype. |
# | **Personalization** | Generates tailored content for marketing, education, entertainment. |
# | **Accessibility** | Creates captions, translations, or assists people with disabilities. |
#
# ---
#
# ## Risks & Challenges
#
# | Issue | What It Means |
# |-------|---------------|
# | **Hallucinations** | The model can produce plausible but incorrect information. |
# | **Bias & Fairness** | Learned from biased data → can reinforce stereotypes. |
# | **Copyright & Ownership** | Generated content may infringe on copyrighted material. |
# | **Misuse** | Deepfakes, disinformation, phishing. |
# | **Energy & Compute** | Training large models consumes massive resources. |
#
# ---
#
# ## How to Use Generative AI Responsibly
#
# 1. **Verify Outputs** – Cross‑check facts, especially for critical applications.
# 2. **Bias Audits** – Test for biased language or outputs.
# 3. **Ethical Guidelines** – Follow industry standards (e.g., AI Ethics Guidelines from OECD).
# 4. **Transparency** – Clearly label AI‑generated content.
# 5. **Data Privacy** – Avoid feeding sensitive personal data into public models.
#
# ---
#
# ## Quick FAQ
#
# | Question | Answer |
# |----------|--------|
# | **Do I need to build my own model?** | For most use cases, you can use APIs (OpenAI, Anthropic, Cohere, etc.) or open‑source models. |
# | **What’s the difference between GPT‑4 and other models?** | GPT‑4 is a transformer‑based language model; others (e.g., diffusion models) are specialized for images. |
# | **Can I fine‑tune GPT‑4?** | As of now, GPT‑4 can be fine‑tuned via “ChatGPT plugins” or “custom instructions,” but full model fine‑tuning isn’t publicly available. |
# | **Is it safe to use in production?** | With proper safeguards (content moderation, hallucination checks, rate limiting), yes. |
#
# ---
#
# ### Bottom Line
#
# Generative AI is a powerful set of tools that lets machines **create** content by learning from vast amounts of data. It’s transforming how we write, design, code, and more—while also demanding careful consideration of ethics, bias, and safety. Whether you’re a developer, artist, marketer, or just curious, understanding the basics of Gen‑AI can help you harness its potential responsibly.
