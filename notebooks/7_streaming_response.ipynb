# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
# Out:
# C:\Users\taman\AppData\Roaming\Python\Python314\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
llm = ChatGroq(model="openai/gpt-oss-20b", streaming=True)

# %%
question = "Can you explain me GEN-AI ?"

# %%
res = llm.stream(question)
for chunk in res:
    print(chunk.content, end="")
# Out:
# **GEN‑AI** is shorthand for **Generative Artificial Intelligence**—the family of machine‑learning models that can *create* new data that looks like it could have come from a real‑world source.  In other words, instead of just *classifying* or *predicting* what comes next, a generative model can *write* a paragraph, *draw* a portrait, *compose* a song, or *synthesize* a realistic video from scratch.
#
# Below is a quick‑start guide that covers what GEN‑AI is, how it works, what it can do, and why it matters.
#
# ---
#
# ## 1. What is Generative AI?
#
# | Aspect | Description |
# |--------|-------------|
# | **Core Idea** | Learn a statistical model of a data distribution and then sample from it. |
# | **Goal** | Produce realistic, high‑quality content that mimics the style or structure of the training data. |
# | **Common Domains** | Text, images, audio, video, 3‑D models, and even code. |
# | **Typical Use‑Cases** | Chatbots, creative writing, art generation, design prototyping, data augmentation, content moderation, and more. |
#
# ---
#
# ## 2. How Does It Work?
#
# Generative AI models can be grouped into a few key families. The most impactful in 2024 are:
#
# | Model Type | Core Technique | Typical Applications | Example Models |
# |------------|----------------|----------------------|----------------|
# | **Transformers** | Self‑attention, autoregressive (predict next token) or auto‑encoding (reconstruct) | Text (ChatGPT, GPT‑4), code (Codex), multimodal (ChatGPT‑4o, Gemini) | GPT‑4, LLaMA, Claude, Gemini |
# | **Diffusion Models** | Iteratively add and remove noise to generate data | Images, audio, video | Stable Diffusion, Imagen, Midjourney, DALL‑E 3 |
# | **GANs (Generative Adversarial Networks)** | Two networks (generator vs discriminator) compete | Early image generation, style transfer | StyleGAN, BigGAN |
# | **VAEs (Variational Autoencoders)** | Probabilistic encoder‑decoder | Latent‑space interpolation, anomaly detection | VAE‑based image models |
# | **Flow‑Based Models** | Exact likelihood, invertible transformations | Image compression, density estimation | RealNVP, Glow |
#
# ### The Typical Pipeline
#
# 1. **Data Collection** – Gather a large corpus of the target domain (e.g., millions of web pages for language, millions of photos for images).
# 2. **Pre‑processing** – Clean, tokenize, or encode the data into a format the model can ingest.
# 3. **Training** – Use massive compute (often GPUs/TPUs) to minimize a loss that encourages the model to learn the data distribution.
# 4. **Sampling / Generation** – Feed the model a prompt or seed; it outputs new data that statistically resembles the training set.
# 5. **Post‑processing** – Filter, refine, or edit the output to meet quality or policy standards.
#
# ---
#
# ## 3. Key Concepts & Terminology
#
# | Term | Meaning |
# |------|---------|
# | **Autoregressive** | Generates data token‑by‑token, each step conditioned on previous tokens (e.g., GPT). |
# | **Diffusion** | Adds noise to data until it becomes pure noise, then learns to reverse the process to generate new samples. |
# | **Latent Space** | A compressed, often lower‑dimensional representation where similar items cluster together. |
# | **Fine‑tuning** | Starting from a pre‑trained model and continuing training on a smaller, domain‑specific dataset. |
# | **Zero‑shot / Few‑shot** | Ability to perform tasks with no or minimal task‑specific examples. |
# | **Prompt Engineering** | Crafting input prompts to steer the model toward desired outputs. |
#
# ---
#
# ## 4. What Can GEN‑AI Do?
#
# | Domain | Examples |
# |--------|----------|
# | **Text** | Chatbots, story generation, summarization, translation, code generation, legal drafting. |
# | **Images** | Portraits, landscapes, product mock‑ups, style transfer, image inpainting, super‑resolution. |
# | **Audio** | Voice cloning, music composition, speech synthesis, sound effect generation. |
# | **Video** | Short clip generation, deep‑fakes (ethical concerns), frame interpolation, video summarization. |
# | **Multimodal** | Captioning images, generating images from text prompts, generating text from images. |
# | **Code** | Auto‑completion, bug detection, documentation generation. |
#
# ### Real‑World Examples
#
# | Product | What It Does |
# |---------|--------------|
# | **ChatGPT (OpenAI)** | Conversational AI that can answer questions, write essays, and even produce code. |
# | **Stable Diffusion** | Open‑source image generator that produces photorealistic or stylized images from text prompts. |
# | **DALL‑E 3** | OpenAI’s text‑to‑image model with advanced prompt understanding. |
# | **Midjourney** | Community‑driven AI art generator that excels at stylistic, surreal outputs. |
# | **Codex** | Code‑generation model that powers GitHub Copilot. |
# | **Google Gemini** | Multimodal model that can handle text, images, and code in one interface. |
#
# ---
#
# ## 5. Why Is It Important?
#
# | Benefit | Explanation |
# |---------|-------------|
# | **Scalability** | One model can handle many tasks across domains, reducing the need for specialized tools. |
# | **Creativity** | Lowers the barrier to creative expression for artists, writers, designers, and entrepreneurs. |
# | **Efficiency** | Automates repetitive or time‑consuming tasks, freeing humans for higher‑value work. |
# | **Accessibility** | Makes advanced content creation tools available to non‑experts (e.g., small businesses). |
# | **Innovation** | Drives new products and services (e.g., AI‑assisted design, personalized education). |
#
# ---
#
# ## 6. Challenges & Risks
#
# | Issue | Impact |
# |-------|--------|
# | **Quality & Hallucinations** | Models can produce plausible but incorrect or nonsensical content. |
# | **Bias & Fairness** | Training data may contain societal biases, leading to discriminatory outputs. |
# | **Copyright & Ownership** | Generated content may inadvertently copy copyrighted material. |
# | **Security** | Potential for malicious use (deepfakes, phishing, disinformation). |
# | **Computational Cost** | Training large models requires significant energy and infrastructure. |
# | **Regulation & Ethics** | Need for transparent policies, user consent, and content moderation. |
#
# ---
#
# ## 7. How to Get Started
#
# 1. **Choose a Model**
#    - *OpenAI GPT‑4o* (text & multimodal).
#    - *Stable Diffusion 2.1* (image).
#    - *Google Gemini* (multimodal).
# 2. **Define Your Use‑Case**
#    - Is it content creation, data augmentation, or something else?
# 3. **Select an API or Open‑Source Framework**
#    - OpenAI, Anthropic, Cohere, Replicate, Hugging Face.
# 4. **Build & Test**
#    - Write simple prompts, iterate on the output.
# 5. **Fine‑Tune (Optional)**
#    - If you need domain‑specific style or jargon, fine‑tune on a curated dataset.
# 6. **Deploy & Monitor**
#    - Set up moderation, rate limits, and usage analytics.
#
# ---
#
# ## 8. Quick FAQ
#
# | Question | Short Answer |
# |----------|--------------|
# | **Is GEN‑AI the same as AGI?** | No. AGI (Artificial General Intelligence) would understand and learn any intellectual task like a human. GEN‑AI is specialized at generating data, not full reasoning. |
# | **Can it replace a human writer?** | It can assist, but human oversight is still crucial for quality, nuance, and ethical considerations. |
# | **Do I need a GPU to use it?** | Most APIs run on cloud GPUs; you only need a CPU to send requests. If you want to run a model locally, a GPU is recommended. |
# | **Is it safe?** | Generally yes, but always use moderation tools and follow best practices to avoid harmful outputs. |
# | **What’s the future?** | Expect better multimodal integration, more efficient models (e.g., sparse transformers), and tighter alignment with human values. |
#
# ---
#
# ## 9. Takeaway
#
# **Generative AI** is a powerful, rapidly evolving set of tools that can *create* realistic text, images, audio, and more. It is built on advanced neural architectures (transformers, diffusion models, GANs) that learn from large datasets and then produce new content conditioned on prompts. While it offers huge opportunities across industries, it also brings challenges—hallucinations, bias, copyright, and ethical use—that must be addressed responsibly.
#
# Feel free to dive deeper into any of the topics above or ask for a hands‑on example (e.g., a prompt that generates a short story or a quick image prompt). Happy exploring!
