# %%
text = "Who is PM of India?"

# %%
import tiktoken

# %%
tokenizer = tiktoken.encoding_for_model(model_name="gpt-4")

# %%
tokenIds = tokenizer.encode(text)
print(tokenIds)
# Out:
# [15546, 374, 5975, 315, 6890, 30]

# %%
resultIds = tokenizer.decode(tokenIds)
print(resultIds)
# Out:
# Who is PM of India?
